# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv("IPL Ball-by-Ball 2008-2020.csv")

# %%
df
# Out:
#              id  inning  over  ball      batsman  non_striker  \
# 0        335982       1     6     5   RT Ponting  BB McCullum
# 1        335982       1     6     6  BB McCullum   RT Ponting
# 2        335982       1     7     1  BB McCullum   RT Ponting
# 3        335982       1     7     2  BB McCullum   RT Ponting
# 4        335982       1     7     3   RT Ponting  BB McCullum
# ...         ...     ...   ...   ...          ...          ...
# 193463  1237181       1    12     5      RR Pant      SS Iyer
# 193464  1237181       1    12     6      RR Pant      SS Iyer
# 193465  1237181       1    13     1      RR Pant      SS Iyer
# 193466  1237181       1    13     2      RR Pant      SS Iyer
# 193467  1237181       1    13     3      SS Iyer      RR Pant
#
#                  bowler  batsman_runs  extra_runs  total_runs  non_boundary  \
# 0             AA Noffke             1           0           1             0
# ...

# %%
z=df.head(500)
z
# Out:
#          id  inning  over  ball      batsman  non_striker     bowler  \
# 0    335982       1     6     5   RT Ponting  BB McCullum  AA Noffke
# 1    335982       1     6     6  BB McCullum   RT Ponting  AA Noffke
# 2    335982       1     7     1  BB McCullum   RT Ponting     Z Khan
# 3    335982       1     7     2  BB McCullum   RT Ponting     Z Khan
# 4    335982       1     7     3   RT Ponting  BB McCullum     Z Khan
# ..      ...     ...   ...   ...          ...          ...        ...
# 495  335984       2    10     1    G Gambhir     S Dhawan   SK Warne
# 496  335984       2    10     2     S Dhawan    G Gambhir   SK Warne
# 497  335984       2    10     3    G Gambhir     S Dhawan   SK Warne
# 498  335984       2    10     4    G Gambhir     S Dhawan   SK Warne
# 499  335984       2    10     5     S Dhawan    G Gambhir   SK Warne
#
#      batsman_runs  extra_runs  total_runs  non_boundary  is_wicket  \
# 0               1           0           1             0          0
# ...

# %%
df.shape
# Out:
# (193468, 18)

# %%
df['is_wicket'].value_counts()#most win rate of ipl
# Out:
# 0    183973
# 1      9495
# Name: is_wicket, dtype: int64

# %%
df.isnull()
# Out:
#            id  inning   over   ball  batsman  non_striker  bowler  \
# 0       False   False  False  False    False        False   False
# 1       False   False  False  False    False        False   False
# 2       False   False  False  False    False        False   False
# 3       False   False  False  False    False        False   False
# 4       False   False  False  False    False        False   False
# ...       ...     ...    ...    ...      ...          ...     ...
# 193463  False   False  False  False    False        False   False
# 193464  False   False  False  False    False        False   False
# 193465  False   False  False  False    False        False   False
# 193466  False   False  False  False    False        False   False
# 193467  False   False  False  False    False        False   False
#
#         batsman_runs  extra_runs  total_runs  non_boundary  is_wicket  \
# 0              False       False       False         False      False
# ...

# %%
df.isna().sum()
# Out:
# id                       0
# inning                   0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# non_boundary             0
# is_wicket                0
# dismissal_kind      183973
# player_dismissed    183973
# fielder             186684
# extras_type         183235
# batting_team             0
# bowling_team           191
# dtype: int64

# %%
df["dismissal_kind"].isnull()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 193463    True
# 193464    True
# 193465    True
# 193466    True
# 193467    True
# Name: dismissal_kind, Length: 193468, dtype: bool

# %%
df["player_dismissed"].isnull()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 193463    True
# 193464    True
# 193465    True
# 193466    True
# 193467    True
# Name: player_dismissed, Length: 193468, dtype: bool

# %%
df.drop(columns="dismissal_kind", inplace = True)
df.head(50)
# Out:
#         id  inning  over  ball      batsman  non_striker     bowler  \
# 0   335982       1     6     5   RT Ponting  BB McCullum  AA Noffke
# 1   335982       1     6     6  BB McCullum   RT Ponting  AA Noffke
# 2   335982       1     7     1  BB McCullum   RT Ponting     Z Khan
# 3   335982       1     7     2  BB McCullum   RT Ponting     Z Khan
# 4   335982       1     7     3   RT Ponting  BB McCullum     Z Khan
# 5   335982       1     7     4  BB McCullum   RT Ponting     Z Khan
# 6   335982       1     7     5   RT Ponting  BB McCullum     Z Khan
# 7   335982       1     7     6  BB McCullum   RT Ponting     Z Khan
# 8   335982       1     8     1  BB McCullum   RT Ponting  JH Kallis
# 9   335982       1     8     2  BB McCullum   RT Ponting  JH Kallis
# 10  335982       1     8     3  BB McCullum   RT Ponting  JH Kallis
# 11  335982       1     8     4  BB McCullum   RT Ponting  JH Kallis
# 12  335982       1     8     5   RT Ponting  BB McCullum  JH Kallis
# ...

# %%
df.drop(columns="player_dismissed", inplace = True)
df.head()
# Out:
#        id  inning  over  ball      batsman  non_striker     bowler  \
# 0  335982       1     6     5   RT Ponting  BB McCullum  AA Noffke
# 1  335982       1     6     6  BB McCullum   RT Ponting  AA Noffke
# 2  335982       1     7     1  BB McCullum   RT Ponting     Z Khan
# 3  335982       1     7     2  BB McCullum   RT Ponting     Z Khan
# 4  335982       1     7     3   RT Ponting  BB McCullum     Z Khan
#
#    batsman_runs  extra_runs  total_runs  non_boundary  is_wicket fielder  \
# 0             1           0           1             0          0     NaN
# 1             1           0           1             0          0     NaN
# 2             0           0           0             0          0     NaN
# 3             1           0           1             0          0     NaN
# 4             1           0           1             0          0     NaN
#
#   extras_type           batting_team                 bowling_team
# ...

# %%
df[df.duplicated(keep=False)]
# Out:
#            id  inning  over  ball       batsman non_striker      bowler  \
# 38363  419152       1     3     1  SR Tendulkar     C Madan  PJ Sangwan
# 38372  419152       1     3     1  SR Tendulkar     C Madan  PJ Sangwan
#
#        batsman_runs  extra_runs  total_runs  non_boundary  is_wicket fielder  \
# 38363             1           0           1             0          0     NaN
# 38372             1           0           1             0          0     NaN
#
#       extras_type    batting_team      bowling_team
# 38363         NaN  Mumbai Indians  Delhi Daredevils
# 38372         NaN  Mumbai Indians  Delhi Daredevils

# %%
plt.scatter(z.index,z['batsman_runs'])
plt.show()

# %%
sns.stripplot(y=z['batsman_runs'])
# Out:
# <AxesSubplot:ylabel='batsman_runs'>

# %%
sns.stripplot(x=z['over'],y=z['batsman_runs'])
# Out:
# <AxesSubplot:xlabel='over', ylabel='batsman_runs'>

# %%
plt.hist(df['batsman_runs'])
# Out:
# (array([7.7637e+04, 7.1937e+04, 0.0000e+00, 1.2408e+04, 0.0000e+00,
#         6.1600e+02, 2.1908e+04, 0.0000e+00, 6.0000e+01, 8.9020e+03]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.stripplot(x = df['over'], y =df['is_wicket'],size=10)
# Out:
# <AxesSubplot:xlabel='over', ylabel='is_wicket'>

# %%
sns.barplot(x='over',y='is_wicket',data=df)
# Out:
# <AxesSubplot:xlabel='over', ylabel='is_wicket'>

# %%
sns.barplot(x='over',y='extra_runs',data=df)
# Out:
# <AxesSubplot:xlabel='over', ylabel='extra_runs'>
